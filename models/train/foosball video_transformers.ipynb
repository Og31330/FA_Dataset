# %% [markdown]
# # Video Classification with Transformers
#
# **Author:** [Sayak Paul](https://twitter.com/RisingSayak)<br>
# **Date created:** 2021/06/08<br>
# **Last modified:** 2023/22/07<br>
# **Description:** Training a video classifier with hybrid transformers.

# %% [markdown]
# This example is a follow-up to the
# [Video Classification with a CNN-RNN Architecture](https://keras.io/examples/vision/video_classification/)
# example. This time, we will be using a Transformer-based model
# ([Vaswani et al.](https://arxiv.org/abs/1706.03762)) to classify videos. You can follow
# [this book chapter](https://livebook.manning.com/book/deep-learning-with-python-second-edition/chapter-11)
# in case you need an introduction to Transformers (with code). After reading this
# example, you will know how to develop hybrid Transformer-based models for video
# classification that operate on CNN feature maps.

# %%
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %% [markdown]
# ## Setup

# %%
import os
import keras
from keras import layers
from keras.applications.densenet import DenseNet121

from tensorflow_docs.vis import embed

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import imageio
import cv2
import glob

# %% [markdown]
# ## Define hyperparameters

# %%
MAX_SEQ_LENGTH = 8
NUM_FEATURES = 1024
IMG_SIZE = 128

EPOCHS = 50

# %% [markdown]
# ## Data preparation
#
# We will mostly be following the same data preparation steps in this example, except for
# the following changes:
#
# * We reduce the image size to 128x128 instead of 224x224 to speed up computation.
# * Instead of using a pre-trained [InceptionV3](https://arxiv.org/abs/1512.00567) network,
# we use a pre-trained
# [DenseNet121](http://openaccess.thecvf.com/content_cvpr_2017/papers/Huang_Densely_Connected_Convolutional_CVPR_2017_paper.pdf)
# for feature extraction.
# * We directly pad shorter videos to length `MAX_SEQ_LENGTH`.
#
# First, let's load up the
# [DataFrames](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html).

# %%
# !unzip -q /content/MoviNet2.zip

# %%
# !mv /content/MoviNet2/val /content/MoviNet2/val2
# !mv /content/MoviNet2/test /content/MoviNet2/val
# !mv /content/MoviNet2/val2 /content/MoviNet2/test

# %%
# !find /content/MoviNet2 -type d -name "Block_2-5.2" -exec rm -r {} +
# !find /content/MoviNet2 -type d -name "Block_1-5.4" -exec rm -r {} +

# %%
#generate csv file
import os
import csv

def generate_csv_from_directory_structure(base_dir, output_csv_files):
    """
    Parcourt une structure de répertoires et génère des fichiers CSV contenant le nom des vidéos et leur classe associée.

    Arguments:
    - base_dir (str): Chemin de la racine des données (par exemple, "Movinet2").
    - output_csv_files (dict): Dictionnaire contenant les sous-répertoires (clé) et les noms des fichiers CSV de sortie (valeur).
    """
    for sub_dir, output_csv in output_csv_files.items():
        sub_dir_path = os.path.join(base_dir, sub_dir)
        rows = []

        # Parcours du sous-répertoire (ex. train, val, test)
        for class_name in os.listdir(sub_dir_path):
            class_path = os.path.join(sub_dir_path, class_name)

            if os.path.isdir(class_path):  # Vérifie si c'est un répertoire
                for video_name in os.listdir(class_path):
                    video_path = os.path.join(class_path, video_name)

                    if os.path.isfile(video_path):
                        rows.append([video_name, class_name])

        # Écriture des données dans un fichier CSV
        with open(output_csv, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(["video_name", "tag"])
            writer.writerows(rows)

        print(f"CSV généré : {output_csv} avec {len(rows)} entrées.")

# Exemple d'utilisation
base_directory = "/content/MoviNet2"
output_files = {
    "train": "train_videos.csv",
    "val": "val_videos.csv",
    "test": "test_videos.csv"
}

generate_csv_from_directory_structure(base_directory, output_files)
# Out:
# CSV généré : train_videos.csv avec 209 entrées.
# CSV généré : val_videos.csv avec 60 entrées.
# CSV généré : test_videos.csv avec 39 entrées.

# %%
train_df = pd.read_csv("train_videos.csv")
val_df = pd.read_csv("val_videos.csv")
test_df = pd.read_csv("test_videos.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

#center_crop_layer = layers.CenterCrop(IMG_SIZE, IMG_SIZE)
# Au lieu de CenterCrop
center_crop_layer = layers.Resizing(IMG_SIZE, IMG_SIZE)



def crop_center(frame):
    cropped = center_crop_layer(frame[None, ...])
    cropped = keras.ops.convert_to_numpy(cropped)
    cropped = keras.ops.squeeze(cropped)
    return cropped


# Following method is modified from this tutorial:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def load_video(path, max_frames=0, offload_to_cpu=False):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = frame[:, :, [2, 1, 0]]
            frame = crop_center(frame)
            if offload_to_cpu and keras.backend.backend() == "torch":
                frame = frame.to("cpu")
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    if offload_to_cpu and keras.backend.backend() == "torch":
        return np.array([frame.to("cpu").numpy() for frame in frames])
    return np.array(frames)


def build_feature_extractor():
    feature_extractor = DenseNet121(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.densenet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()


# Label preprocessing with StringLookup.
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"]), mask_token=None
)
print(label_processor.get_vocabulary())
# Out:
# Total videos for training: 209
# Total videos for testing: 39
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [np.str_('Block_1-2.1'), np.str_('Block_1-2.2'), np.str_('Block_1-3.3'), np.str_('Block_1-5.1'), np.str_('Block_2-1'), np.str_('Control_1-2.1'), np.str_('Control_1-2.2'), np.str_('Control_1-3.1'), np.str_('Control_1-3.2'), np.str_('Control_1-3.3'), np.str_('Control_1-5.1'), np.str_('Control_1-5.3'), np.str_('Control_1-5.4'), np.str_('Control_1-5.5'), np.str_('Control_2-1'), np.str_('Control_2-2.1'), np.str_('Control_2-2.2'), np.str_('Control_2-3.1'), np.str_('Control_2-3.2'), np.str_('Control_2-3.3'), np.str_('Control_2-5.1'), np.str_('Control_2-5.2'), np.str_('Control_2-5.3'), np.str_('Control_2-5.5'), np.str_('Kick off'), np.str_('Other'), np.str_('Roll'), np.str_('Shot_1-3.2'), np.str_('Shot_2-2.2'), np.str_('Shot_2-3.2')]

# %%
# Liste des éléments
data = label_processor.get_vocabulary()

# Nom du fichier texte
output_file = "labels.txt"

# Sauvegarde dans le fichier texte
with open(output_file, "w") as file:
    for item in data:
        file.write(item + "\n")

print(f"Les données ont été sauvegardées dans le fichier : {output_file}")
# Out:
# Les données ont été sauvegardées dans le fichier : labels.txt

# %%
def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()
    raw_labels = df["tag"].values  # Labels non transformés (nom des classes)

    # `frame_features` are what we will feed to our sequence model.
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        # Récupérer le nom de la classe à partir du DataFrame
        class_label = raw_labels[idx]
        # Construire le chemin vers le dossier de la classe
        class_folder = os.path.join(root_dir, class_label)
        # Construire le chemin complet vers la vidéo
        video_path = os.path.join(class_folder, path)
        print(os.path.join(video_path, path))
        frames = load_video(video_path)

        # Pad shorter videos.
        print (len(frames))
        if len(frames) < MAX_SEQ_LENGTH:
            diff = MAX_SEQ_LENGTH - len(frames)
            padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
            frames = np.concatenate(frames, padding)

        frames = frames[None, ...]

        # Initialize placeholder to store the features of the current video.
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                if np.mean(batch[j, :]) > 0.0:
                    temp_frame_features[i, j, :] = feature_extractor.predict(
                        batch[None, j, :]
                    )

                else:
                    temp_frame_features[i, j, :] = 0.0

        frame_features[idx,] = temp_frame_features.squeeze()

    return frame_features, labels

train_data, train_labels = prepare_all_videos(train_df, "/content/MoviNet2/train")
val_data, val_labels = prepare_all_videos(val_df, "/content/MoviNet2/val")
test_data, test_labels = prepare_all_videos(test_df, "/content/MoviNet2/test")

print(f"Frame features in train set: {train_data.shape}")
print(f"Frame features in val set: {val_data.shape}")
print(f"Frame features in test set: {test_data.shape}")
# Out:
# /content/MoviNet2/train/Control_1-2.1/CNFT2Toulouse_Control_2109.avi/CNFT2Toulouse_Control_2109.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /content/MoviNet2/train/Control_1-2.1/CNFT2Toulouse_Control_2071.avi/CNFT2Toulouse_Control_2071.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# /content/MoviNet2/train/Control_1-2.1/CNFT2Toulouse_Control_2088.avi/CNFT2Toulouse_Control_2088.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# /content/MoviNet2/train/Control_1-2.1/CNFT2Toulouse_Control_2125.avi/CNFT2Toulouse_Control_2125.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_552.avi/CNFT2Toulouse_Control_552.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_555.avi/CNFT2Toulouse_Control_555.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_528.avi/CNFT2Toulouse_Control_528.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_523.avi/CNFT2Toulouse_Control_523.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_517.avi/CNFT2Toulouse_Control_517.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_518.avi/CNFT2Toulouse_Control_518.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_548.avi/CNFT2Toulouse_Control_548.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# /content/MoviNet2/train/Control_1-5.1/CNFT2Toulouse_Control_533.avi/CNFT2Toulouse_Control_533.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /content/MoviNet2/train/Block_1-5.1/CNFT2Toulouse_Block_1194.avi/CNFT2Toulouse_Block_1194.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# /content/MoviNet2/train/Block_1-5.1/CNFT2Toulouse_Block_1196.avi/CNFT2Toulouse_Block_1196.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3571.avi/CNFT2Toulouse_Control_3571.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3587.avi/CNFT2Toulouse_Control_3587.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3553.avi/CNFT2Toulouse_Control_3553.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3596.avi/CNFT2Toulouse_Control_3596.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3555.avi/CNFT2Toulouse_Control_3555.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3561.avi/CNFT2Toulouse_Control_3561.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_16.avi/CNFT2Toulouse_Control_16.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# /content/MoviNet2/train/Control_1-5.3/CNFT2Toulouse_Control_3626.avi/CNFT2Toulouse_Control_3626.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_918.avi/CNFT2Toulouse_Control_918.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_3293.avi/CNFT2Toulouse_Control_3293.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_917.avi/CNFT2Toulouse_Control_917.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_923.avi/CNFT2Toulouse_Control_923.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_3298.avi/CNFT2Toulouse_Control_3298.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_3292.avi/CNFT2Toulouse_Control_3292.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_1556.avi/CNFT2Toulouse_Control_1556.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# /content/MoviNet2/train/Control_2-3.1/CNFT2Toulouse_Control_924.avi/CNFT2Toulouse_Control_924.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3270.avi/CNFT2Toulouse_Shot_3270.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3272.avi/CNFT2Toulouse_Shot_3272.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3268.avi/CNFT2Toulouse_Shot_3268.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3271.avi/CNFT2Toulouse_Shot_3271.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3273.avi/CNFT2Toulouse_Shot_3273.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# /content/MoviNet2/train/Shot_2-2.2/CNFT2Toulouse_Shot_3269.avi/CNFT2Toulouse_Shot_3269.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_328.avi/CNFT2Toulouse_Control_328.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_2641.avi/CNFT2Toulouse_Control_2641.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_2575.avi/CNFT2Toulouse_Control_2575.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_313.avi/CNFT2Toulouse_Control_313.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_2563.avi/CNFT2Toulouse_Control_2563.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_2613.avi/CNFT2Toulouse_Control_2613.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /content/MoviNet2/train/Control_2-5.3/CNFT2Toulouse_Control_384.avi/CNFT2Toulouse_Control_384.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# /content/MoviNet2/train/Roll/CNFT2Toulouse_Roll_1204.avi/CNFT2Toulouse_Roll_1204.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# /content/MoviNet2/train/Roll/CNFT2Toulouse_Roll_1731.avi/CNFT2Toulouse_Roll_1731.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# /content/MoviNet2/train/Roll/CNFT2Toulouse_Roll_3282.avi/CNFT2Toulouse_Roll_3282.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# /content/MoviNet2/train/Roll/CNFT2Toulouse_Roll_1999.avi/CNFT2Toulouse_Roll_1999.avi
# 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %% [markdown]
# ## Building the Transformer-based model
#
# We will be building on top of the code shared in
# [this book chapter](https://livebook.manning.com/book/deep-learning-with-python-second-edition/chapter-11) of
# [Deep Learning with Python (Second ed.)](https://www.manning.com/books/deep-learning-with-python)
# by François Chollet.
#
# First, self-attention layers that form the basic blocks of a Transformer are
# order-agnostic. Since videos are ordered sequences of frames, we need our
# Transformer model to take into account order information.
# We do this via **positional encoding**.
# We simply embed the positions of the frames present inside videos with an
# [`Embedding` layer](https://keras.io/api/layers/core_layers/embedding). We then
# add these positional embeddings to the precomputed CNN feature maps.

# %%
@keras.saving.register_keras_serializable()
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def build(self, input_shape):
        self.position_embeddings.build(input_shape)

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        inputs = keras.ops.cast(inputs, self.compute_dtype)
        length = keras.ops.shape(inputs)[1]
        positions = keras.ops.arange(start=0, stop=length, step=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

# %% [markdown]
# Now, we can create a subclassed layer for the Transformer.

# %%
@keras.saving.register_keras_serializable()
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation=keras.activations.gelu),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %% [markdown]
# ## Utility functions for training

# %%
def get_compiled_model(shape):
    sequence_length = MAX_SEQ_LENGTH
    embed_dim = NUM_FEATURES
    dense_dim = 4
    num_heads = 1
    classes = len(label_processor.get_vocabulary())

    inputs = keras.Input(shape=shape)
    x = PositionalEmbedding(
        sequence_length, embed_dim, name="frame_position_embedding"
    )(inputs)
    x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(classes, activation="softmax")(x)
    model = keras.Model(inputs, outputs)

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model


def run_experiment():
    filepath = "/content/video_classifier.weights.keras"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=False, save_best_only=True, verbose=1
    )

    model = get_compiled_model(train_data.shape[1:])
    history = model.fit(
      train_data,
      train_labels,
      validation_data=(val_data, val_labels),  # Utilisation des données de validation explicites
      epochs=EPOCHS,
     callbacks=[checkpoint],
    )

    model.load_weights(filepath)
    _, accuracy = model.evaluate(val_data, val_labels)
    print(f"Val accuracy: {round(accuracy * 100, 2)}%")

    _, accuracy = model.evaluate(test_data, test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return model

# %% [markdown]
# ## Model training and inference

# %%
trained_model = run_experiment()
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.0604 - loss: 5.9153
# Epoch 1: val_loss improved from inf to 4.23265, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.0630 - loss: 5.9032 - val_accuracy: 0.0500 - val_loss: 4.2327
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 899ms/step - accuracy: 0.0871 - loss: 4.9160
# Epoch 2: val_loss improved from 4.23265 to 3.62044, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.0906 - loss: 4.8931 - val_accuracy: 0.2167 - val_loss: 3.6204
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 905ms/step - accuracy: 0.0909 - loss: 4.2179
# Epoch 3: val_loss did not improve from 3.62044
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 960ms/step - accuracy: 0.0897 - loss: 4.2228 - val_accuracy: 0.0500 - val_loss: 3.6339
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1829 - loss: 3.5893
# Epoch 4: val_loss improved from 3.62044 to 3.39617, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.1786 - loss: 3.6105 - val_accuracy: 0.1000 - val_loss: 3.3962
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 876ms/step - accuracy: 0.1022 - loss: 3.6008
# Epoch 5: val_loss improved from 3.39617 to 3.37443, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 964ms/step - accuracy: 0.1019 - loss: 3.6132 - val_accuracy: 0.1500 - val_loss: 3.3744
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.1223 - loss: 3.7928
# Epoch 6: val_loss did not improve from 3.37443
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 929ms/step - accuracy: 0.1201 - loss: 3.7974 - val_accuracy: 0.2333 - val_loss: 3.4260
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1521 - loss: 3.6991
# Epoch 7: val_loss improved from 3.37443 to 3.28358, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1516 - loss: 3.6975 - val_accuracy: 0.2167 - val_loss: 3.2836
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1741 - loss: 3.4191
# Epoch 8: val_loss improved from 3.28358 to 3.18588, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.1768 - loss: 3.4121 - val_accuracy: 0.2167 - val_loss: 3.1859
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.1957 - loss: 3.3589
# Epoch 9: val_loss improved from 3.18588 to 3.06941, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 963ms/step - accuracy: 0.1940 - loss: 3.3682 - val_accuracy: 0.2167 - val_loss: 3.0694
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2296 - loss: 3.0673
# Epoch 10: val_loss improved from 3.06941 to 2.93690, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2278 - loss: 3.0755 - val_accuracy: 0.2333 - val_loss: 2.9369
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1683 - loss: 2.9140
# Epoch 11: val_loss did not improve from 2.93690
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.1706 - loss: 2.9217 - val_accuracy: 0.3167 - val_loss: 2.9426
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2146 - loss: 2.7693
# Epoch 12: val_loss improved from 2.93690 to 2.91305, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2159 - loss: 2.7732 - val_accuracy: 0.1833 - val_loss: 2.9130
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 886ms/step - accuracy: 0.3190 - loss: 2.4830
# Epoch 13: val_loss improved from 2.91305 to 2.27050, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 981ms/step - accuracy: 0.3204 - loss: 2.4856 - val_accuracy: 0.4333 - val_loss: 2.2705
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4823 - loss: 1.9479
# Epoch 14: val_loss improved from 2.27050 to 2.01535, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4764 - loss: 1.9608 - val_accuracy: 0.4500 - val_loss: 2.0153
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5236 - loss: 1.5487
# Epoch 15: val_loss improved from 2.01535 to 1.82768, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.5240 - loss: 1.5503 - val_accuracy: 0.5333 - val_loss: 1.8277
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5172 - loss: 1.4976
# Epoch 16: val_loss improved from 1.82768 to 1.63691, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.5154 - loss: 1.5086 - val_accuracy: 0.6000 - val_loss: 1.6369
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5832 - loss: 1.4375
# Epoch 17: val_loss did not improve from 1.63691
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5815 - loss: 1.4511 - val_accuracy: 0.5500 - val_loss: 1.7720
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5739 - loss: 1.3272
# Epoch 18: val_loss improved from 1.63691 to 1.32647, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5775 - loss: 1.3151 - val_accuracy: 0.6000 - val_loss: 1.3265
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.7125 - loss: 0.9181
# Epoch 19: val_loss did not improve from 1.32647
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 909ms/step - accuracy: 0.7138 - loss: 0.9096 - val_accuracy: 0.7167 - val_loss: 1.5569
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7692 - loss: 0.8324
# Epoch 20: val_loss did not improve from 1.32647
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7664 - loss: 0.8462 - val_accuracy: 0.5333 - val_loss: 2.2741
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.6991 - loss: 1.0965
# Epoch 21: val_loss did not improve from 1.32647
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6913 - loss: 1.1201 - val_accuracy: 0.5833 - val_loss: 1.7864
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.6503 - loss: 1.0632
# Epoch 22: val_loss did not improve from 1.32647
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 903ms/step - accuracy: 0.6504 - loss: 1.0644 - val_accuracy: 0.6833 - val_loss: 1.5265
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7951 - loss: 0.6864
# Epoch 23: val_loss improved from 1.32647 to 1.08809, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7938 - loss: 0.6835 - val_accuracy: 0.7500 - val_loss: 1.0881
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8073 - loss: 0.5105
# Epoch 24: val_loss did not improve from 1.08809
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8057 - loss: 0.5192 - val_accuracy: 0.7833 - val_loss: 1.4775
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8162 - loss: 0.6164
# Epoch 25: val_loss did not improve from 1.08809
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8140 - loss: 0.6233 - val_accuracy: 0.6000 - val_loss: 1.9264
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7907 - loss: 0.6683
# Epoch 26: val_loss did not improve from 1.08809
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7935 - loss: 0.6593 - val_accuracy: 0.7333 - val_loss: 1.3254
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.8888 - loss: 0.3699
# Epoch 27: val_loss did not improve from 1.08809
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 935ms/step - accuracy: 0.8877 - loss: 0.3710 - val_accuracy: 0.7833 - val_loss: 1.2876
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9242 - loss: 0.3273
# Epoch 28: val_loss did not improve from 1.08809
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9199 - loss: 0.3354 - val_accuracy: 0.7500 - val_loss: 1.5341
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8859 - loss: 0.3535
# Epoch 29: val_loss improved from 1.08809 to 0.98594, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 984ms/step - accuracy: 0.8816 - loss: 0.3660 - val_accuracy: 0.8333 - val_loss: 0.9859
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8932 - loss: 0.2603
# Epoch 30: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8904 - loss: 0.2666 - val_accuracy: 0.7667 - val_loss: 1.3419
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8664 - loss: 0.3121
# Epoch 31: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8669 - loss: 0.3142 - val_accuracy: 0.8167 - val_loss: 1.1203
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9205 - loss: 0.2165
# Epoch 32: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9178 - loss: 0.2250 - val_accuracy: 0.8000 - val_loss: 1.3445
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 995ms/step - accuracy: 0.9537 - loss: 0.1580
# Epoch 33: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9541 - loss: 0.1593 - val_accuracy: 0.7333 - val_loss: 1.6925
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9294 - loss: 0.1893
# Epoch 34: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9293 - loss: 0.1895 - val_accuracy: 0.8000 - val_loss: 1.5285
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9226 - loss: 0.1843
# Epoch 35: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9251 - loss: 0.1845 - val_accuracy: 0.7667 - val_loss: 1.8229
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9392 - loss: 0.1869
# Epoch 36: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9379 - loss: 0.1863 - val_accuracy: 0.8000 - val_loss: 1.3886
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9691 - loss: 0.1216
# Epoch 37: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 913ms/step - accuracy: 0.9664 - loss: 0.1302 - val_accuracy: 0.8167 - val_loss: 1.5643
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9121 - loss: 0.2163
# Epoch 38: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9123 - loss: 0.2179 - val_accuracy: 0.7500 - val_loss: 1.2650
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.8750 - loss: 0.2957
# Epoch 39: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 929ms/step - accuracy: 0.8769 - loss: 0.2914 - val_accuracy: 0.7500 - val_loss: 1.4452
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.9040 - loss: 0.2934
# Epoch 40: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 917ms/step - accuracy: 0.9004 - loss: 0.2997 - val_accuracy: 0.8000 - val_loss: 1.3503
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - accuracy: 0.9474 - loss: 0.2038
# Epoch 41: val_loss did not improve from 0.98594
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 956ms/step - accuracy: 0.9468 - loss: 0.2062 - val_accuracy: 0.7500 - val_loss: 1.7047
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9566 - loss: 0.1214
# Epoch 42: val_loss improved from 0.98594 to 0.92804, saving model to /content/video_classifier.weights.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9530 - loss: 0.1286 - val_accuracy: 0.8333 - val_loss: 0.9280
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.9692 - loss: 0.0817
# Epoch 43: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 899ms/step - accuracy: 0.9683 - loss: 0.0851 - val_accuracy: 0.7667 - val_loss: 1.5859
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.9321 - loss: 0.1694
# Epoch 44: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 900ms/step - accuracy: 0.9346 - loss: 0.1676 - val_accuracy: 0.8333 - val_loss: 1.5627
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9390 - loss: 0.1498
# Epoch 45: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 907ms/step - accuracy: 0.9358 - loss: 0.1593 - val_accuracy: 0.8167 - val_loss: 1.7040
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9514 - loss: 0.1521
# Epoch 46: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9521 - loss: 0.1512 - val_accuracy: 0.8167 - val_loss: 1.3676
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.9207 - loss: 0.1906
# Epoch 47: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 937ms/step - accuracy: 0.9205 - loss: 0.1933 - val_accuracy: 0.8167 - val_loss: 1.6883
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 886ms/step - accuracy: 0.9067 - loss: 0.1759
# Epoch 48: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 929ms/step - accuracy: 0.9076 - loss: 0.1781 - val_accuracy: 0.8333 - val_loss: 1.6748
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9679 - loss: 0.1046
# Epoch 49: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9647 - loss: 0.1121 - val_accuracy: 0.7000 - val_loss: 1.8172
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.9688 - loss: 0.1770
# Epoch 50: val_loss did not improve from 0.92804
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 918ms/step - accuracy: 0.9674 - loss: 0.1796 - val_accuracy: 0.8000 - val_loss: 1.7517
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8576 - loss: 0.7752
# Val accuracy: 83.33%
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8454 - loss: 1.4512
# Test accuracy: 84.62%

# %% [markdown]
# **Note**: This model has ~4.23 Million parameters, which is way more than the sequence
# model (99918 parameters) we used in the prequel of this example.  This kind of
# Transformer model works best with a larger dataset and a longer pre-training schedule.

# %% [markdown]
# ## Test on single data from Test dataset

# %%
def prepare_single_video(frames):
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    # Pad shorter videos.
    if len(frames) < MAX_SEQ_LENGTH:
        diff = MAX_SEQ_LENGTH - len(frames)
        padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate(frames, padding)

    frames = frames[None, ...]

    # Extract features from the frames of the current video.
    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            if np.mean(batch[j, :]) > 0.0:
                frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
            else:
                frame_features[i, j, :] = 0.0

    return frame_features


def predict_action(path):
    class_vocab = label_processor.get_vocabulary()

    file_path = glob.glob(os.path.join("/content/MoviNet2/test", "**", path), recursive=True)
    print(file_path[0])

    frames = load_video(file_path[0], offload_to_cpu=True)
    frame_features = prepare_single_video(frames)
    probabilities = trained_model.predict(frame_features)[0]

    plot_x_axis, plot_y_axis = [], []

    # Sélectionner les 5 meilleures classes avec leurs probabilités
    top_5_indices = np.argsort(probabilities)[::-1][:5]

    for i in top_5_indices:
        plot_x_axis.append(class_vocab[i])
        plot_y_axis.append(probabilities[i])
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")

    plt.bar(plot_x_axis, plot_y_axis, label=plot_x_axis)
    plt.xlabel("class_label")
    plt.xlabel("Probability")
    plt.show()

    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=2, loop=0)
    return embed.embed_file("animation.gif")


test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")
test_frames = predict_action(test_video)
to_gif(test_frames[:MAX_SEQ_LENGTH])

# %% [markdown]
# The performance of our model is far from optimal, because it was trained on a small dataset.

# %% [markdown]
# ##Test on single data from Val dataset

# %%
# test on video from val dataset
def prepare_single_video(frames):
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    # Pad shorter videos.
    if len(frames) < MAX_SEQ_LENGTH:
        diff = MAX_SEQ_LENGTH - len(frames)
        padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate(frames, padding)

    frames = frames[None, ...]

    # Extract features from the frames of the current video.
    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            if np.mean(batch[j, :]) > 0.0:
                frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
            else:
                frame_features[i, j, :] = 0.0

    return frame_features


def predict_action(path):
    class_vocab = label_processor.get_vocabulary()

    file_path = glob.glob(os.path.join("/content/MoviNet2/val", "**", path), recursive=True)
    print(file_path[0])

    frames = load_video(file_path[0], offload_to_cpu=True)
    frame_features = prepare_single_video(frames)
    probabilities = trained_model.predict(frame_features)[0]

    plot_x_axis, plot_y_axis = [], []

    # Sélectionner les 5 meilleures classes avec leurs probabilités
    top_5_indices = np.argsort(probabilities)[::-1][:5]

    for i in top_5_indices:
        plot_x_axis.append(class_vocab[i])
        plot_y_axis.append(probabilities[i])
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")

    plt.bar(plot_x_axis, plot_y_axis, label=plot_x_axis)
    plt.xlabel("class_label")
    plt.xlabel("Probability")
    plt.show()

    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=2, loop=0)
    return embed.embed_file("animation.gif")


val_video = np.random.choice(val_df["video_name"].values.tolist())
print(f"Val video path: {val_video}")
val_frames = predict_action(val_video)
to_gif(val_frames[:MAX_SEQ_LENGTH])
# Out:
# Val video path: CNFT2Toulouse_Roll_1027.avi
# /content/MoviNet2/val/Roll/CNFT2Toulouse_Roll_1027.avi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
#   Roll: 100.00%
#   Control_2-5.1:  0.00%
#   Control_2-3.3:  0.00%
#   Control_2-3.1:  0.00%
#   Shot_2-3.2:  0.00%
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# #Deploiement dans Gradio

# %%
# !pip install --upgrade gradio huggingface_hub

# %%
import os
import keras
from keras import layers
from keras.applications.densenet import DenseNet121

from tensorflow_docs.vis import embed

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import imageio
import cv2
import glob

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
import cv2
import os
import keras
from keras import layers
from keras.saving import register_keras_serializable
#from keras.applications.densenet import DenseNet121
from tensorflow_docs.vis import embed



# Charger le modèle Keras
MAX_SEQ_LENGTH = 8
NUM_FEATURES = 1024
IMG_SIZE = 128

@keras.saving.register_keras_serializable()
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim

    def build(self, input_shape):
        self.position_embeddings.build(input_shape)

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        inputs = keras.ops.cast(inputs, self.compute_dtype)
        length = keras.ops.shape(inputs)[1]
        positions = keras.ops.arange(start=0, stop=length, step=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

@keras.saving.register_keras_serializable()
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation=keras.activations.gelu),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)


model = tf.keras.models.load_model("/content/video_classifier.weights.keras")

# Liste des classes du modèle
# Nom du fichier de classe
input_file = "/content/labels.txt"
# Lecture du fichier et création de la liste
with open(input_file, "r") as file:
    class_labels = [line.strip() for line in file]
print("Tableau recréé à partir du fichier :")
print(class_labels)


# test on video from val dataset
def prepare_single_video(frames):
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    # Pad shorter videos.
    if len(frames) < MAX_SEQ_LENGTH:
        diff = MAX_SEQ_LENGTH - len(frames)
        padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
        frames = np.concatenate(frames, padding)

    frames = frames[None, ...]

    # Extract features from the frames of the current video.
    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            if np.mean(batch[j, :]) > 0.0:
                frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
            else:
                frame_features[i, j, :] = 0.0

    return frame_features


async def predict_action(video):
    frames = load_video(video, offload_to_cpu=True)
    frame_features = prepare_single_video(frames)
    probabilities = trained_model.predict(frame_features)[0]
    # Obtenir le top 5
    top_5_indices = np.argsort(probabilities)[::-1][:5]
    results = {class_labels[i]: float(probabilities[i]) for i in top_5_indices}
    return results

# Créer l'interface Gradio
app = gr.Interface(
    fn=predict_action,
    inputs=gr.Video(label="Téléchargez une vidéo", live = True),
    outputs=gr.Label(num_top_classes=5, label="Top 5 Classes Prédites"),
    title="Analyseur de Vidéo IA",
    description="Téléchargez une vidéo pour identifier les classes principales grâce à un modèle IA entraîné."
)


# Lancer l'application
if __name__ == "__main__":
    app.launch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     717         try:
# --> 718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/model.py in from_config(cls, config, custom_objects)
#     524
# --> 525             return functional_from_config(
#     526                 cls, config, custom_objects=custom_objects
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in functional_from_config(cls, config, custom_objects)
#     476     for layer_data in config["layers"]:
# --> 477         process_layer(layer_data)
#     478
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in process_layer(layer_data)
#     460         else:
# --> 461             layer = serialization_lib.deserialize_keras_object(
#     462                 layer_data, custom_objects=custom_objects
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     693
# --> 694     cls = _retrieve_class_or_fn(
#     695         class_name,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     811
# --> 812     raise TypeError(
#     813         f"Could not locate {obj_type} '{name}'. "
#
# TypeError: Could not locate class 'PositionalEmbedding'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': None, 'class_name': 'PositionalEmbedding', 'config': {'name': 'frame_position_embedding', 'sequence_length': 8, 'output_dim': 1024, 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}, 'registered_name': 'PositionalEmbedding', 'build_config': {'input_shape': [None, 8, 1024]}, 'name': 'frame_position_embedding', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 8, 1024], 'dtype': 'float32', 'keras_history': ['input_layer_4', 0, 0]}}], 'kwargs': {}}]}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c04fde6a247c> in <cell line: 66>()
#      64
#      65
# ---> 66 model = tf.keras.models.load_model("/content/video_classifier.weights.keras")
#      67
#      68 # Liste des classes du modèle
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     185
#     186     if is_keras_zip or is_keras_dir:
# --> 187         return saving_lib.load_model(
#     188             filepath,
#     189             custom_objects=custom_objects,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in load_model(filepath, custom_objects, compile, safe_mode)
#     363             )
#     364         with open(filepath, "rb") as f:
# --> 365             return _load_model_from_fileobj(
#     366                 f, custom_objects, compile, safe_mode
#     367             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     440             config_json = f.read()
#     441
# --> 442         model = _model_from_config(
#     443             config_json, custom_objects, compile, safe_mode
#     444         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     429     # Construct the model from the configuration file in the archive.
#     430     with ObjectSharingScope():
# --> 431         model = deserialize_keras_object(
#     432             config_dict, custom_objects, safe_mode=safe_mode
#     433         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/serialization_lib.py in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     718             instance = cls.from_config(inner_config)
#     719         except TypeError as e:
# --> 720             raise TypeError(
#     721                 f"{cls} could not be deserialized properly. Please"
#     722                 " ensure that components that are Python object"
#
# TypeError: <class 'keras.src.models.functional.Functional'> could not be deserialized properly. Please ensure that components that are Python object instances (layers, models, etc.) returned by `get_config()` are explicitly deserialized in the model's `from_config()` method.
#
# config={'module': 'keras.src.models.functional', 'class_name': 'Functional', 'config': {'name': 'functional_3', 'trainable': True, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': [None, 8, 1024], 'dtype': 'float32', 'sparse': False, 'name': 'input_layer_4'}, 'registered_name': None, 'name': 'input_layer_4', 'inbound_nodes': []}, {'module': None, 'class_name': 'PositionalEmbedding', 'config': {'name': 'frame_position_embedding', 'sequence_length': 8, 'output_dim': 1024, 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}, 'registered_name': 'PositionalEmbedding', 'build_config': {'input_shape': [None, 8, 1024]}, 'name': 'frame_position_embedding', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 8, 1024], 'dtype': 'float32', 'keras_history': ['input_layer_4', 0, 0]}}], 'kwargs': {}}]}, {'module': None, 'class_name': 'TransformerEncoder', 'config': {'name': 'transformer_layer', 'embed_dim': 1024, 'dense_dim': 4, 'num_heads': 1, 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None, 'shared_object_id': 133559778286688}}, 'registered_name': 'TransformerEncoder', 'build_config': {'input_shape': [None, 8, 1024]}, 'name': 'transformer_layer', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 8, 1024]...
#
# Exception encountered: Could not locate class 'PositionalEmbedding'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': None, 'class_name': 'PositionalEmbedding', 'config': {'name': 'frame_position_embedding', 'sequence_length': 8, 'output_dim': 1024, 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}}, 'registered_name': 'PositionalEmbedding', 'build_config': {'input_shape': [None, 8, 1024]}, 'name': 'frame_position_embedding', 'inbound_nodes': [{'args': [{'class_name': '__keras_tensor__', 'config': {'shape': [None, 8, 1024], 'dtype': 'float32', 'keras_history': ['input_layer_4', 0, 0]}}], 'kwargs': {}}]}

# %%
from huggingface_hub import login

# Remplacez "YOUR_TOKEN" par votre token Hugging Face
login("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")

# %%
# Déployer sur Hugging Face
app.push_to_hub("myFirstGradioSpace", space_description="Une application Gradio d'exemple")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d6d6834daa3d> in <cell line: 2>()
#       1 # Déployer sur Hugging Face
# ----> 2 app.push_to_hub("myFirstGradioSpace", space_description="Une application Gradio d'exemple")
#
# AttributeError: 'Interface' object has no attribute 'push_to_hub'

# %%
# Available backend options are: "jax", "torch", "tensorflow".
import os
os.environ["KERAS_BACKEND"] = "jax"

import keras

model = keras.saving.load_model("hf://Og2/video_classifier.weights")
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-10-98c3707c7f28> in <cell line: 7>()
#       5 import keras
#       6
# ----> 7 model = keras.saving.load_model("hf://Og2/video_classifier.weights")
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     177
#     178         # Copy from remote to temporary local directory
# --> 179         file_utils.copy(filepath, local_path)
#     180
#     181         # Switch filepath to local zipfile for loading model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/file_utils.py in copy(src, dst)
#     476     if is_remote_path(src) or is_remote_path(dst):
#     477         if gfile.available:
# --> 478             return gfile.copy(src, dst, overwrite=True)
#     479         else:
#     480             _raise_if_no_gfile(f"src={src} dst={dst}")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py in copy_v2(src, dst, overwrite)
#     579     errors.OpError: If the operation fails.
#     580   """
# --> 581   _pywrap_file_io.CopyFile(
#     582       compat.path_to_bytes(src), compat.path_to_bytes(dst), overwrite)
#     583
#
# UnimplementedError: File system scheme 'hf' not implemented (file: 'hf://Og2/video_classifier.weights')

# %%
from huggingface_hub import hf_hub_download
import tensorflow as tf

login("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")

# Télécharger le fichier depuis Hugging Face
model_path = hf_hub_download(repo_id="Og2/video_classifier", filename="video_classifier.weights.keras")

# Charger le modèle Keras depuis le chemin local
model = tf.keras.models.load_model(model_path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/Og2/video_classifier/resolve/main/video_classifier.weights.keras
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# <ipython-input-14-6b1d6cb5f5e5> in <cell line: 7>()
#       5
#       6 # Télécharger le fichier depuis Hugging Face
# ----> 7 model_path = hf_hub_download(repo_id="Og2/video_classifier", filename="video_classifier.weights.keras")
#       8
#       9 # Charger le modèle Keras depuis le chemin local
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     858         )
#     859     else:
# --> 860         return _hf_hub_download_to_cache_dir(
#     861             # Destination
#     862             cache_dir=cache_dir,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     965
#     966         # Otherwise, raise appropriate error
# --> 967         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#     968
#     969     # From now on, etag, commit_hash, url and size are not None.
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1480     elif isinstance(head_call_error, RepositoryNotFoundError) or isinstance(head_call_error, GatedRepoError):
#    1481         # Repo not found or gated => let's raise the actual error
# -> 1482         raise head_call_error
#    1483     else:
#    1484         # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1372         try:
#    1373             try:
# -> 1374                 metadata = get_hf_file_metadata(
#    1375                     url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1376                 )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1292
#    1293     # Retrieve metadata
# -> 1294     r = _request_wrapper(
#    1295         method="HEAD",
#    1296         url=url,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     276     # Recursively follow relative redirects
#     277     if follow_relative_redirects:
# --> 278         response = _request_wrapper(
#     279             method=method,
#     280             url=url,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     300     # Perform request and return if status_code is not in the retry list.
#     301     response = get_session().request(method=method, url=url, **params)
# --> 302     hf_raise_for_status(response)
#     303     return response
#     304
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     452                 " make sure you are authenticated."
#     453             )
# --> 454             raise _format(RepositoryNotFoundError, message, response) from e
#     455
#     456         elif response.status_code == 400:
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-67882dbd-649623b93bebb1061fa0fadf;0e228371-5f54-4455-8306-e961c789059a)
#
# Repository Not Found for url: https://huggingface.co/Og2/video_classifier/resolve/main/video_classifier.weights.keras.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated.

# %%
from gradio_client import Client, file

# Connect to your Gradio Space
client = Client("Og2/myFirstGradioSpace")

# Chemin vers votre fichier local
local_file_path = "/content/CNFT2Toulouse_Block_1729.avi"

# Préparer l'objet vidéo
video_data = {"video": file(local_file_path), "subtitles": None}

# Envoyer la requête à l'API
result = client.predict(video=video_data, api_name="/predict")

# Afficher le résultat
print(result)
# Out:
# Loaded as API: https://og2-myfirstgradiospace.hf.space ✔
# {'label': 'Block_1-2.1', 'confidences': [{'label': 'Block_1-2.1', 'confidence': 0.5897575616836548}, {'label': 'Roll', 'confidence': 0.37092286348342896}, {'label': 'Shot_2-3.2', 'confidence': 0.036071859300136566}, {'label': 'Control_2-3.2', 'confidence': 0.0013297920813784003}, {'label': 'Control_2-3.1', 'confidence': 0.000599658174905926}]}
